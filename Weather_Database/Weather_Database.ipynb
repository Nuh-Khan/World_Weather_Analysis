# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high= 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high= 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 777

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        max_temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        cloudiness = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']
        weatherdesc = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({'City':city.title(),
                          'Lat':lat,
                          'Lng':lng,
                          'Max Temp':max_temp,
                          'Humidity':humidity,
                          'Cloudiness':cloudiness,
                          'Wind Speed':wind,
                          'Country':country,
                          'Current Description':weatherdesc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | san ignacio
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | te anau
# Processing Record 6 of Set 1 | svetlaya
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | pangody
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | port hedland
# Processing Record 13 of Set 1 | nelson bay
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | fairbanks
# Processing Record 16 of Set 1 | katherine
# Processing Record 17 of Set 1 | pokanayevka
# City not found. Skipping...
# Processing Record 18 of Set 1 | kudahuvadhoo
# Processing Record 19 of Set 1 | buzmeyin
# Processing Record 20 of Set 1 | mezen
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | la gomera
# Processing Record 23 of Set 1 | ha giang
# Processing Record 24 of Set 1 | georgetown
# Processing Record 25 of Set 1 | bembereke
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | anse-bertrand
# Processing Record 29 of Set 1 | dongkan
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | vestmannaeyjar
# Processing Record 32 of Set 1 | duku
# Processing Record 33 of Set 1 | harlingen
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | tasiilaq
# Processing Record 36 of Set 1 | anderson
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | klyuchevskiy
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | burica
# City not found. Skipping...
# Processing Record 43 of Set 1 | santa cecilia
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | lasa
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | baruun-urt
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | providencia
# Processing Record 5 of Set 2 | tiksi
# Processing Record 6 of Set 2 | ust-nera
# Processing Record 7 of Set 2 | hofn
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | soledad
# Processing Record 10 of Set 2 | saryozek
# Processing Record 11 of Set 2 | rocha
# Processing Record 12 of Set 2 | faya
# Processing Record 13 of Set 2 | saint-francois
# Processing Record 14 of Set 2 | gao
# Processing Record 15 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 2 | necochea
# Processing Record 17 of Set 2 | amapa
# Processing Record 18 of Set 2 | aksu
# Processing Record 19 of Set 2 | svetlogorsk
# Processing Record 20 of Set 2 | port-cartier
# Processing Record 21 of Set 2 | waipawa
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 2 | ghanzi
# Processing Record 25 of Set 2 | atbasar
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | terney
# Processing Record 32 of Set 2 | beira
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | sibu
# Processing Record 35 of Set 2 | marshall
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | kirakira
# Processing Record 38 of Set 2 | gorom-gorom
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | korla
# Processing Record 41 of Set 2 | sayyan
# Processing Record 42 of Set 2 | kazuno
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | maniitsoq
# Processing Record 45 of Set 2 | kruisfontein
# Processing Record 46 of Set 2 | iqaluit
# Processing Record 47 of Set 2 | skibbereen
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | guane
# Processing Record 4 of Set 3 | maku
# Processing Record 5 of Set 3 | yerbogachen
# Processing Record 6 of Set 3 | marsh harbour
# Processing Record 7 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 3 | cherskiy
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | najran
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | garden city
# Processing Record 14 of Set 3 | iquitos
# Processing Record 15 of Set 3 | wana
# Processing Record 16 of Set 3 | bardiyah
# Processing Record 17 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 3 | adrar
# Processing Record 19 of Set 3 | troitskoye
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 3 | formosa do rio preto
# Processing Record 23 of Set 3 | leh
# Processing Record 24 of Set 3 | williston
# Processing Record 25 of Set 3 | mount isa
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | okato
# Processing Record 28 of Set 3 | sangolqui
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | sambava
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | vanimo
# Processing Record 33 of Set 3 | sao joao da barra
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | yverdon
# City not found. Skipping...
# Processing Record 36 of Set 3 | dongzhen
# Processing Record 37 of Set 3 | axim
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | huicheng
# Processing Record 40 of Set 3 | vrangel
# Processing Record 41 of Set 3 | normandin
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | kropotkin
# Processing Record 46 of Set 3 | beloha
# Processing Record 47 of Set 3 | peleduy
# Processing Record 48 of Set 3 | bethel
# Processing Record 49 of Set 3 | treinta y tres
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | winburg
# Processing Record 3 of Set 4 | nuuk
# Processing Record 4 of Set 4 | krasnoselkup
# Processing Record 5 of Set 4 | hobart
# Processing Record 6 of Set 4 | kieta
# Processing Record 7 of Set 4 | asfi
# Processing Record 8 of Set 4 | niamey
# Processing Record 9 of Set 4 | bandarbeyla
# Processing Record 10 of Set 4 | chaiyaphum
# Processing Record 11 of Set 4 | thiruvananthapuram
# Processing Record 12 of Set 4 | grindavik
# Processing Record 13 of Set 4 | sechura
# Processing Record 14 of Set 4 | padang
# Processing Record 15 of Set 4 | zapolyarnyy
# Processing Record 16 of Set 4 | tura
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | marsassoum
# Processing Record 19 of Set 4 | belmonte
# Processing Record 20 of Set 4 | xichang
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | bella union
# Processing Record 23 of Set 4 | taperoa
# Processing Record 24 of Set 4 | bengkulu
# Processing Record 25 of Set 4 | saint-joseph
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | nadapuram
# Processing Record 29 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 30 of Set 4 | orlik
# Processing Record 31 of Set 4 | maceio
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | ahipara
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | mirnyy
# Processing Record 37 of Set 4 | avon park
# Processing Record 38 of Set 4 | khandyga
# Processing Record 39 of Set 4 | mount gambier
# Processing Record 40 of Set 4 | goure
# Processing Record 41 of Set 4 | cairns
# Processing Record 42 of Set 4 | paciran
# Processing Record 43 of Set 4 | oborniki
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | tuktoyaktuk
# Processing Record 47 of Set 4 | whitianga
# Processing Record 48 of Set 4 | ostrovnoy
# Processing Record 49 of Set 4 | kulachi
# Processing Record 50 of Set 4 | poltavka
# Processing Record 1 of Set 5 | port hardy
# Processing Record 2 of Set 5 | narathiwat
# Processing Record 3 of Set 5 | hirara
# Processing Record 4 of Set 5 | moissala
# Processing Record 5 of Set 5 | hay river
# Processing Record 6 of Set 5 | asyut
# Processing Record 7 of Set 5 | gogrial
# Processing Record 8 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 5 | evensk
# Processing Record 10 of Set 5 | maymyo
# Processing Record 11 of Set 5 | pangnirtung
# Processing Record 12 of Set 5 | lima
# Processing Record 13 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 14 of Set 5 | smolyaninovo
# Processing Record 15 of Set 5 | karpogory
# Processing Record 16 of Set 5 | quatre cocos
# Processing Record 17 of Set 5 | port elizabeth
# Processing Record 18 of Set 5 | tibacuy
# Processing Record 19 of Set 5 | boden
# Processing Record 20 of Set 5 | bagh
# Processing Record 21 of Set 5 | hami
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | akdepe
# Processing Record 24 of Set 5 | osoyoos
# Processing Record 25 of Set 5 | hailar
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | cockburn town
# Processing Record 29 of Set 5 | benicarlo
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | yeniseysk
# Processing Record 33 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 5 | ayan
# Processing Record 35 of Set 5 | iralaya
# Processing Record 36 of Set 5 | lebu
# Processing Record 37 of Set 5 | poum
# Processing Record 38 of Set 5 | quang ngai
# Processing Record 39 of Set 5 | tilichiki
# Processing Record 40 of Set 5 | wanning
# City not found. Skipping...
# Processing Record 41 of Set 5 | taoudenni
# Processing Record 42 of Set 5 | leshukonskoye
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 46 of Set 5 | vila velha
# Processing Record 47 of Set 5 | fare
# Processing Record 48 of Set 5 | meridian
# Processing Record 49 of Set 5 | clarence town
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | guerrero negro
# Processing Record 4 of Set 6 | ayagoz
# Processing Record 5 of Set 6 | faanui
# Processing Record 6 of Set 6 | grande prairie
# Processing Record 7 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 6 | santa isabel do rio negro
# Processing Record 9 of Set 6 | rabo de peixe
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | kismayo
# Processing Record 12 of Set 6 | upernavik
# Processing Record 13 of Set 6 | katsuura
# Processing Record 14 of Set 6 | la palma
# Processing Record 15 of Set 6 | portales
# Processing Record 16 of Set 6 | kodiak
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | kalulushi
# Processing Record 19 of Set 6 | katha
# City not found. Skipping...
# Processing Record 20 of Set 6 | qandala
# Processing Record 21 of Set 6 | beatrice
# Processing Record 22 of Set 6 | ust-kuyga
# Processing Record 23 of Set 6 | ancud
# Processing Record 24 of Set 6 | mitsamiouli
# Processing Record 25 of Set 6 | plettenberg bay
# Processing Record 26 of Set 6 | ferme-neuve
# Processing Record 27 of Set 6 | dolores
# Processing Record 28 of Set 6 | puerto del rosario
# Processing Record 29 of Set 6 | batagay
# Processing Record 30 of Set 6 | torbay
# Processing Record 31 of Set 6 | thompson
# Processing Record 32 of Set 6 | hryshkivtsi
# Processing Record 33 of Set 6 | pa sang
# Processing Record 34 of Set 6 | chlorakas
# Processing Record 35 of Set 6 | paamiut
# Processing Record 36 of Set 6 | sao filipe
# Processing Record 37 of Set 6 | bubaque
# Processing Record 38 of Set 6 | bonavista
# Processing Record 39 of Set 6 | saint paul
# Processing Record 40 of Set 6 | sangar
# Processing Record 41 of Set 6 | mandvi
# Processing Record 42 of Set 6 | belaya gora
# Processing Record 43 of Set 6 | clyde river
# Processing Record 44 of Set 6 | nortelandia
# Processing Record 45 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 6 | huarmey
# Processing Record 47 of Set 6 | olafsvik
# Processing Record 48 of Set 6 | lao cai
# Processing Record 49 of Set 6 | victoria
# Processing Record 50 of Set 6 | alto araguaia
# Processing Record 1 of Set 7 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 7 | zalesovo
# Processing Record 3 of Set 7 | maragogi
# Processing Record 4 of Set 7 | kingsport
# Processing Record 5 of Set 7 | banamba
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | suzun
# Processing Record 9 of Set 7 | nador
# Processing Record 10 of Set 7 | dallas
# Processing Record 11 of Set 7 | portgordon
# Processing Record 12 of Set 7 | haines junction
# Processing Record 13 of Set 7 | grand gaube
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | tierralta
# Processing Record 16 of Set 7 | tiznit
# Processing Record 17 of Set 7 | xining
# Processing Record 18 of Set 7 | moerai
# Processing Record 19 of Set 7 | betare oya
# Processing Record 20 of Set 7 | sabha
# Processing Record 21 of Set 7 | namibe
# Processing Record 22 of Set 7 | puerto carreno
# Processing Record 23 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 7 | alihe
# Processing Record 25 of Set 7 | henties bay
# Processing Record 26 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 27 of Set 7 | khani
# Processing Record 28 of Set 7 | merauke
# Processing Record 29 of Set 7 | benguela
# Processing Record 30 of Set 7 | esperance
# Processing Record 31 of Set 7 | broken hill
# Processing Record 32 of Set 7 | penzance
# Processing Record 33 of Set 7 | tautira
# Processing Record 34 of Set 7 | arraial do cabo
# Processing Record 35 of Set 7 | vila do maio
# Processing Record 36 of Set 7 | tornio
# Processing Record 37 of Set 7 | porto nacional
# Processing Record 38 of Set 7 | timizart
# Processing Record 39 of Set 7 | moche
# Processing Record 40 of Set 7 | beyneu
# Processing Record 41 of Set 7 | sadove
# Processing Record 42 of Set 7 | payo
# Processing Record 43 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 7 | vao
# Processing Record 45 of Set 7 | kuala kedah
# Processing Record 46 of Set 7 | nemuro
# Processing Record 47 of Set 7 | odienne
# Processing Record 48 of Set 7 | presidente olegario
# Processing Record 49 of Set 7 | kashi
# Processing Record 50 of Set 7 | puteyets
# Processing Record 1 of Set 8 | le creusot
# Processing Record 2 of Set 8 | bondo
# Processing Record 3 of Set 8 | geraldton
# Processing Record 4 of Set 8 | disna
# Processing Record 5 of Set 8 | mollendo
# Processing Record 6 of Set 8 | bonthe
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 8 | husavik
# Processing Record 10 of Set 8 | east london
# Processing Record 11 of Set 8 | ust-maya
# Processing Record 12 of Set 8 | conakry
# Processing Record 13 of Set 8 | beibei
# Processing Record 14 of Set 8 | roald
# Processing Record 15 of Set 8 | kajaani
# Processing Record 16 of Set 8 | sorong
# Processing Record 17 of Set 8 | loreto
# Processing Record 18 of Set 8 | naze
# Processing Record 19 of Set 8 | eyl
# Processing Record 20 of Set 8 | la ronge
# Processing Record 21 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 8 | benton harbor
# Processing Record 23 of Set 8 | turan
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | yulara
# Processing Record 26 of Set 8 | fairfield
# Processing Record 27 of Set 8 | sao felix do xingu
# Processing Record 28 of Set 8 | kamenka
# Processing Record 29 of Set 8 | snasa
# Processing Record 30 of Set 8 | tiarei
# Processing Record 31 of Set 8 | obihiro
# Processing Record 32 of Set 8 | pacifica
# Processing Record 33 of Set 8 | shache
# Processing Record 34 of Set 8 | lata
# Processing Record 35 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 8 | mahwa
# Processing Record 37 of Set 8 | khovu-aksy
# Processing Record 38 of Set 8 | fairlie
# Processing Record 39 of Set 8 | odweyne
# Processing Record 40 of Set 8 | pacific grove
# Processing Record 41 of Set 8 | balaipungut
# Processing Record 42 of Set 8 | kasempa
# Processing Record 43 of Set 8 | tomigusuku
# Processing Record 44 of Set 8 | kendal
# Processing Record 45 of Set 8 | viedma
# Processing Record 46 of Set 8 | jining
# Processing Record 47 of Set 8 | aksarka
# Processing Record 48 of Set 8 | kindu
# Processing Record 49 of Set 8 | batagay-alyta
# Processing Record 50 of Set 8 | benjamin constant
# Processing Record 1 of Set 9 | gualeguay
# Processing Record 2 of Set 9 | bagdarin
# Processing Record 3 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 9 | nouadhibou
# Processing Record 5 of Set 9 | gejiu
# Processing Record 6 of Set 9 | domoni
# Processing Record 7 of Set 9 | boyuibe
# Processing Record 8 of Set 9 | la union
# Processing Record 9 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 9 | prince rupert
# Processing Record 11 of Set 9 | ukiah
# Processing Record 12 of Set 9 | huangnihe
# Processing Record 13 of Set 9 | lakatoro
# Processing Record 14 of Set 9 | marica
# Processing Record 15 of Set 9 | cao bang
# Processing Record 16 of Set 9 | atikokan
# Processing Record 17 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 9 | bambous virieux
# Processing Record 19 of Set 9 | surovatikha
# Processing Record 20 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 9 | shieli
# Processing Record 22 of Set 9 | cabano
# Processing Record 23 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 9 | halifax
# Processing Record 25 of Set 9 | manggar
# Processing Record 26 of Set 9 | ballitoville
# Processing Record 27 of Set 9 | pochutla
# Processing Record 28 of Set 9 | piranhas
# Processing Record 29 of Set 9 | mae hong son
# Processing Record 30 of Set 9 | meulaboh
# Processing Record 31 of Set 9 | wajima
# Processing Record 32 of Set 9 | severo-kurilsk
# Processing Record 33 of Set 9 | manaure
# Processing Record 34 of Set 9 | college
# Processing Record 35 of Set 9 | manjakandriana
# Processing Record 36 of Set 9 | buenos aires
# Processing Record 37 of Set 9 | nanortalik
# Processing Record 38 of Set 9 | morehead
# Processing Record 39 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 9 | inhambane
# Processing Record 41 of Set 9 | ariyalur
# Processing Record 42 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 9 | zhezkazgan
# Processing Record 44 of Set 9 | omboue
# Processing Record 45 of Set 9 | nuevo laredo
# Processing Record 46 of Set 9 | kavaratti
# Processing Record 47 of Set 9 | petukhovo
# Processing Record 48 of Set 9 | zinder
# Processing Record 49 of Set 9 | lagoa
# Processing Record 50 of Set 9 | sisimiut
# Processing Record 1 of Set 10 | narkanda
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | algiers
# Processing Record 4 of Set 10 | berbera
# Processing Record 5 of Set 10 | sao jose da coroa grande
# Processing Record 6 of Set 10 | fort nelson
# Processing Record 7 of Set 10 | kisiwani
# Processing Record 8 of Set 10 | sampit
# Processing Record 9 of Set 10 | varnamo
# Processing Record 10 of Set 10 | chalmette
# Processing Record 11 of Set 10 | linxia
# Processing Record 12 of Set 10 | hendrina
# Processing Record 13 of Set 10 | dunedin
# Processing Record 14 of Set 10 | tessalit
# Processing Record 15 of Set 10 | armeria
# Processing Record 16 of Set 10 | namtsy
# Processing Record 17 of Set 10 | kuala terengganu
# Processing Record 18 of Set 10 | namatanai
# Processing Record 19 of Set 10 | ambilobe
# Processing Record 20 of Set 10 | abakaliki
# Processing Record 21 of Set 10 | branca
# Processing Record 22 of Set 10 | kurilsk
# Processing Record 23 of Set 10 | yeghegnut
# Processing Record 24 of Set 10 | wau
# Processing Record 25 of Set 10 | baiyin
# Processing Record 26 of Set 10 | ler
# Processing Record 27 of Set 10 | kutum
# Processing Record 28 of Set 10 | visakhapatnam
# Processing Record 29 of Set 10 | farah
# Processing Record 30 of Set 10 | kizema
# Processing Record 31 of Set 10 | graaff-reinet
# Processing Record 32 of Set 10 | tevaitoa
# Processing Record 33 of Set 10 | porto novo
# Processing Record 34 of Set 10 | zatoka
# Processing Record 35 of Set 10 | baherden
# Processing Record 36 of Set 10 | loyga
# Processing Record 37 of Set 10 | ahuimanu
# Processing Record 38 of Set 10 | banyo
# Processing Record 39 of Set 10 | coquimbo
# Processing Record 40 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 10 | bogorodskoye
# Processing Record 42 of Set 10 | roma
# Processing Record 43 of Set 10 | yabrud
# Processing Record 44 of Set 10 | oksfjord
# Processing Record 45 of Set 10 | mabaruma
# Processing Record 46 of Set 10 | kiama
# Processing Record 47 of Set 10 | bulungu
# Processing Record 48 of Set 10 | puksoozero
# Processing Record 49 of Set 10 | marystown
# Processing Record 50 of Set 10 | grand-lahou
# Processing Record 1 of Set 11 | male
# Processing Record 2 of Set 11 | nhulunbuy
# Processing Record 3 of Set 11 | aldergrove
# Processing Record 4 of Set 11 | tshane
# Processing Record 5 of Set 11 | blairmore
# Processing Record 6 of Set 11 | sampang
# Processing Record 7 of Set 11 | saint-augustin
# Processing Record 8 of Set 11 | la libertad
# Processing Record 9 of Set 11 | nieuw amsterdam
# Processing Record 10 of Set 11 | mbanza-ngungu
# Processing Record 11 of Set 11 | kyabe
# Processing Record 12 of Set 11 | waddan
# Processing Record 13 of Set 11 | sabratah
# Processing Record 14 of Set 11 | bilibino
# Processing Record 15 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 11 | yara
# Processing Record 17 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 11 | pathein
# Processing Record 19 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 11 | zhetybay
# City not found. Skipping...
# Processing Record 21 of Set 11 | ericeira
# Processing Record 22 of Set 11 | mitchell
# Processing Record 23 of Set 11 | tual
# Processing Record 24 of Set 11 | pelotas
# Processing Record 25 of Set 11 | richmond
# Processing Record 26 of Set 11 | kikwit
# Processing Record 27 of Set 11 | mercedes
# Processing Record 28 of Set 11 | talas
# Processing Record 29 of Set 11 | buraydah
# Processing Record 30 of Set 11 | caidian
# Processing Record 31 of Set 11 | mzimba
# Processing Record 32 of Set 11 | hong gai
# Processing Record 33 of Set 11 | sola
# Processing Record 34 of Set 11 | del rio
# Processing Record 35 of Set 11 | rio gallegos
# Processing Record 36 of Set 11 | port hueneme
# Processing Record 37 of Set 11 | quimper
# Processing Record 38 of Set 11 | hualmay
# Processing Record 39 of Set 11 | kolobrzeg
# Processing Record 40 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 11 | ati
# Processing Record 43 of Set 11 | asau
# Processing Record 44 of Set 11 | mitu
# Processing Record 45 of Set 11 | bosaso
# Processing Record 46 of Set 11 | liverpool
# Processing Record 47 of Set 11 | port macquarie
# Processing Record 48 of Set 11 | naryan-mar
# Processing Record 49 of Set 11 | banagher
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 12 | melenki
# Processing Record 2 of Set 12 | sehithwa
# Processing Record 3 of Set 12 | okhotsk
# Processing Record 4 of Set 12 | carutapera
# Processing Record 5 of Set 12 | richards bay
# Processing Record 6 of Set 12 | el viejo
# Processing Record 7 of Set 12 | athabasca
# Processing Record 8 of Set 12 | laguna de perlas
# Processing Record 9 of Set 12 | mahibadhoo
# Processing Record 10 of Set 12 | sterling
# Processing Record 11 of Set 12 | qasigiannguit
# Processing Record 12 of Set 12 | lewiston
# Processing Record 13 of Set 12 | gat
# Processing Record 14 of Set 12 | winona
# Processing Record 15 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 12 | dawlatabad
# Processing Record 17 of Set 12 | bilma
# Processing Record 18 of Set 12 | zyryanka
# Processing Record 19 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 12 | san alberto
# Processing Record 21 of Set 12 | porto santo
# Processing Record 22 of Set 12 | tucumcari
# Processing Record 23 of Set 12 | gornyy
# Processing Record 24 of Set 12 | temuco
# Processing Record 25 of Set 12 | swan river
# Processing Record 26 of Set 12 | rapid city
# Processing Record 27 of Set 12 | nesbyen
# Processing Record 28 of Set 12 | saint-louis
# Processing Record 29 of Set 12 | marawi
# Processing Record 30 of Set 12 | katobu
# Processing Record 31 of Set 12 | los llanos de aridane
# Processing Record 32 of Set 12 | aygedzor
# Processing Record 33 of Set 12 | mocuba
# Processing Record 34 of Set 12 | limenaria
# Processing Record 35 of Set 12 | vysokogornyy
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | toamasina
# Processing Record 38 of Set 12 | madang
# Processing Record 39 of Set 12 | vredendal
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | farrukhnagar
# Processing Record 42 of Set 12 | palmerston
# Processing Record 43 of Set 12 | amudalavalasa
# Processing Record 44 of Set 12 | srostki
# Processing Record 45 of Set 12 | westport
# Processing Record 46 of Set 12 | visby
# Processing Record 47 of Set 12 | christchurch
# Processing Record 48 of Set 12 | pisco
# Processing Record 49 of Set 12 | poronaysk
# Processing Record 50 of Set 12 | ossora
# Processing Record 1 of Set 13 | tahoua
# Processing Record 2 of Set 13 | rovaniemi
# Processing Record 3 of Set 13 | salym
# Processing Record 4 of Set 13 | fort frances
# Processing Record 5 of Set 13 | antofagasta
# Processing Record 6 of Set 13 | kazachinskoye
# Processing Record 7 of Set 13 | salta
# Processing Record 8 of Set 13 | aykhal
# Processing Record 9 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 10 of Set 13 | sinnamary
# Processing Record 11 of Set 13 | thinadhoo
# Processing Record 12 of Set 13 | mayo
# Processing Record 13 of Set 13 | beringovskiy
# Processing Record 14 of Set 13 | sandakan
# Processing Record 15 of Set 13 | boshnyakovo
# Processing Record 16 of Set 13 | wuda
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | agadir
# Processing Record 19 of Set 13 | revelstoke
# Processing Record 20 of Set 13 | nyurba
# Processing Record 21 of Set 13 | tuatapere
# Processing Record 22 of Set 13 | luan
# Processing Record 23 of Set 13 | artyom
# Processing Record 24 of Set 13 | springfield
# Processing Record 25 of Set 13 | sorland
# Processing Record 26 of Set 13 | lobito
# Processing Record 27 of Set 13 | san diego de la union
# Processing Record 28 of Set 13 | yishui
# Processing Record 29 of Set 13 | hobyo
# Processing Record 30 of Set 13 | bulgan
# Processing Record 31 of Set 13 | cidreira
# Processing Record 32 of Set 13 | rapar
# Processing Record 33 of Set 13 | nara
# Processing Record 34 of Set 13 | barra do garcas
# Processing Record 35 of Set 13 | bilaspur
# Processing Record 36 of Set 13 | sterlibashevo
# Processing Record 37 of Set 13 | vagur
# Processing Record 38 of Set 13 | cabra
# Processing Record 39 of Set 13 | araouane
# Processing Record 40 of Set 13 | te karaka
# Processing Record 41 of Set 13 | leo
# Processing Record 42 of Set 13 | russellville
# Processing Record 43 of Set 13 | karratha
# Processing Record 44 of Set 13 | cascais
# Processing Record 45 of Set 13 | muros
# Processing Record 46 of Set 13 | pafos
# Processing Record 47 of Set 13 | lakes entrance
# Processing Record 48 of Set 13 | ciudad bolivar
# Processing Record 49 of Set 13 | gigmoto
# Processing Record 50 of Set 13 | buala
# Processing Record 1 of Set 14 | oktyabrskiy
# Processing Record 2 of Set 14 | palora
# Processing Record 3 of Set 14 | sinazongwe
# Processing Record 4 of Set 14 | helena
# Processing Record 5 of Set 14 | caravelas
# Processing Record 6 of Set 14 | arawa
# Processing Record 7 of Set 14 | constitucion
# Processing Record 8 of Set 14 | karatuzskoye
# Processing Record 9 of Set 14 | ruwi
# Processing Record 10 of Set 14 | sivaki
# Processing Record 11 of Set 14 | sinop
# Processing Record 12 of Set 14 | nabire
# Processing Record 13 of Set 14 | jiexiu
# Processing Record 14 of Set 14 | puerto ayacucho
# Processing Record 15 of Set 14 | kupang
# Processing Record 16 of Set 14 | zabid
# Processing Record 17 of Set 14 | goderich
# Processing Record 18 of Set 14 | agadez
# Processing Record 19 of Set 14 | apodi
# Processing Record 20 of Set 14 | peace river
# Processing Record 21 of Set 14 | villazon
# Processing Record 22 of Set 14 | newport
# Processing Record 23 of Set 14 | saint-pierre
# Processing Record 24 of Set 14 | salinopolis
# Processing Record 25 of Set 14 | yeppoon
# Processing Record 26 of Set 14 | tlahualilo
# City not found. Skipping...
# Processing Record 27 of Set 14 | ixtapa
# Processing Record 28 of Set 14 | poway
# Processing Record 29 of Set 14 | gorontalo
# Processing Record 30 of Set 14 | port-gentil
# Processing Record 31 of Set 14 | boffa
# Processing Record 32 of Set 14 | itapora
# Processing Record 33 of Set 14 | warrnambool
# Processing Record 34 of Set 14 | hinton
# Processing Record 35 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 14 | saint-raymond
# Processing Record 37 of Set 14 | colomi
# Processing Record 38 of Set 14 | high level
# Processing Record 39 of Set 14 | road town
# Processing Record 40 of Set 14 | molteno
# Processing Record 41 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 42 of Set 14 | yatou
# Processing Record 43 of Set 14 | sur
# Processing Record 44 of Set 14 | remontnoye
# Processing Record 45 of Set 14 | sheridan
# Processing Record 46 of Set 14 | nome
# Processing Record 47 of Set 14 | honiara
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | rorvik
# Processing Record 50 of Set 14 | cururupu
# Processing Record 1 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 2 of Set 15 | jamame
# Processing Record 3 of Set 15 | alvaraes
# Processing Record 4 of Set 15 | guozhen
# Processing Record 5 of Set 15 | odate
# Processing Record 6 of Set 15 | lodja
# Processing Record 7 of Set 15 | xadani
# City not found. Skipping...
# Processing Record 8 of Set 15 | arroyo
# Processing Record 9 of Set 15 | safakulevo
# Processing Record 10 of Set 15 | cabedelo
# Processing Record 11 of Set 15 | bontang
# Processing Record 12 of Set 15 | kichmengskiy gorodok
# Processing Record 13 of Set 15 | xuddur
# Processing Record 14 of Set 15 | conde
# Processing Record 15 of Set 15 | norsup
# Processing Record 16 of Set 15 | poya
# Processing Record 17 of Set 15 | juneau
# Processing Record 18 of Set 15 | tabas
# Processing Record 19 of Set 15 | mikropolis
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | acarau
# Processing Record 22 of Set 15 | anzhero-sudzhensk
# Processing Record 23 of Set 15 | ozernovskiy
# Processing Record 24 of Set 15 | ajaccio
# Processing Record 25 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 15 | vitim
# Processing Record 27 of Set 15 | bose
# Processing Record 28 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 15 | shurugwi
# Processing Record 30 of Set 15 | taksimo
# Processing Record 31 of Set 15 | quelimane
# Processing Record 32 of Set 15 | kawalu
# Processing Record 33 of Set 15 | borama
# City not found. Skipping...
# Processing Record 34 of Set 15 | nizwa
# Processing Record 35 of Set 15 | seoul
# Processing Record 36 of Set 15 | chingirlau
# Processing Record 37 of Set 15 | abay
# Processing Record 38 of Set 15 | bowen
# Processing Record 39 of Set 15 | apache junction
# Processing Record 40 of Set 15 | camapua
# Processing Record 41 of Set 15 | andenes
# Processing Record 42 of Set 15 | santa maria
# Processing Record 43 of Set 15 | oxbow
# Processing Record 44 of Set 15 | adwa
# Processing Record 45 of Set 15 | ishigaki
# Processing Record 46 of Set 15 | ayr
# Processing Record 47 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 48 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 15 | lumeje
# Processing Record 50 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 16 | olga
# Processing Record 2 of Set 16 | ciomas
# Processing Record 3 of Set 16 | coahuayana
# Processing Record 4 of Set 16 | hambantota
# Processing Record 5 of Set 16 | khormuj
# City not found. Skipping...
# Processing Record 6 of Set 16 | shaunavon
# Processing Record 7 of Set 16 | barranca de upia
# Processing Record 8 of Set 16 | eskasem
# City not found. Skipping...
# Processing Record 9 of Set 16 | port hawkesbury
# Processing Record 10 of Set 16 | morgan city
# Processing Record 11 of Set 16 | houma
# Processing Record 12 of Set 16 | independence
# Processing Record 13 of Set 16 | borovoy
# Processing Record 14 of Set 16 | neverkino
# Processing Record 15 of Set 16 | natchitoches
# Processing Record 16 of Set 16 | amazar
# Processing Record 17 of Set 16 | yazykovo
# Processing Record 18 of Set 16 | vidim
# Processing Record 19 of Set 16 | metsovon
# City not found. Skipping...
# Processing Record 20 of Set 16 | waingapu
# Processing Record 21 of Set 16 | miles city
# Processing Record 22 of Set 16 | at-bashi
# Processing Record 23 of Set 16 | san cristobal
# Processing Record 24 of Set 16 | lokachi
# Processing Record 25 of Set 16 | arman
# Processing Record 26 of Set 16 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 16 | punta alta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 714

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     35.26        69          75
# 1     San Ignacio  17.1561  -89.0714    102.34        37          20
# 2           Bluff -46.6000  168.3333     52.81        77          31
# 3     Port Alfred -33.5906   26.8910     63.18        76          11
# 4         Te Anau -45.4167  167.7167     54.95        79          46
# 5        Svetlaya  46.5389  138.3297     32.58        97         100
# 6     New Norfolk -42.7826  147.0587     49.71        63          39
# 7  Ribeira Grande  38.5167  -28.7000     64.78        94         100
# 8     Provideniya  64.3833 -173.3000     22.98        86          94
# 9         Pangody  65.8500   74.4859     17.42        89          68
#
#    Wind Speed Country Current Description
# 0       16.11      AR          light snow
# 1        4.61      BZ          few clouds
# 2        9.17      NZ    scattered clouds
# 3        4.00      ZA          few clouds
# 4        0.87      NZ    scattered clouds
# 5       25.26      RU                snow
# 6        2.84      AU    scattered clouds
# 7       21.00      PT          light rain
# 8       16.35      RU     overcast clouds
# 9       18.97      RU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columnReorder = ['City', 'Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[columnReorder]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     35.26        69          75
# 1      San Ignacio      BZ  17.1561  -89.0714    102.34        37          20
# 2            Bluff      NZ -46.6000  168.3333     52.81        77          31
# 3      Port Alfred      ZA -33.5906   26.8910     63.18        76          11
# 4          Te Anau      NZ -45.4167  167.7167     54.95        79          46
# ..             ...     ...      ...       ...       ...       ...         ...
# 709       At-Bashi      KG  41.1702   75.8106     45.41        52          32
# 710  San Cristobal      VE   7.7669  -72.2250     82.58        84         100
# 711        Lokachi      UA  50.7370   24.6494     43.75        75          41
# 712          Arman      RU  59.7000  150.1667     30.02        81          17
# 713     Punta Alta      AR -38.8759  -62.0736     77.07        39          64
#
#      Wind Speed Current Description
# 0         16.11          light snow
# 1          4.61          few clouds
# 2          9.17    scattered clouds
# 3          4.00          few clouds
# 4          0.87    scattered clouds
# ..          ...                 ...
# 709        2.37    scattered clouds
# 710        4.12     overcast clouds
# 711        7.85    scattered clouds
# 712        2.35          few clouds
# 713        7.49       broken clouds
#
# [714 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_output = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_output, index_label= "City_ID")
